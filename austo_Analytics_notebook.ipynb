# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("austo_automobile.csv")

# %%
df.head()
# to show top 5 records
# Out:
#    Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 0   53    Male   Business        Married  Post Graduate                 4
# 1   53   Femal   Salaried        Married  Post Graduate                 4
# 2   53  Female   Salaried        Married  Post Graduate                 3
# 3   53  Female   Salaried        Married       Graduate                 2
# 4   53    Male   Salaried        Married  Post Graduate                 3
#
#   Personal_loan House_loan Partner_working  Salary  Partner_salary  \
# 0            No         No             Yes   99300         70700.0
# 1           Yes         No             Yes   95500         70300.0
# 2            No         No             Yes   97300         60700.0
# 3           Yes         No             Yes   72500         70300.0
# 4            No         No             Yes   79700         60200.0
#
#    Total_salary  Price Make
# 0        170000  61000  SUV
# 1        165800  61000  SUV
# 2        158000  57000  SUV
# ...

# %%
#DAta profiling

# %%
df.shape
# to check the total rows and columns -1581 rows,14 col
# Out:
# (1581, 14)

# %%
df.isnull().sum()
# to check the null value in data
# Out:
# Age                   0
# Gender               53
# Profession            0
# Marital_status        0
# Education             0
# No_of_Dependents      0
# Personal_loan         0
# House_loan            0
# Partner_working       0
# Salary                0
# Partner_salary      106
# Total_salary          0
# Price                 0
# Make                  0
# dtype: int64

# %%
df.describe()  # to check the difference in data
# Out:
#                Age  No_of_Dependents        Salary  Partner_salary  \
# count  1581.000000       1581.000000   1581.000000     1475.000000
# mean     31.922201          2.457938  60392.220114    20225.559322
# std       8.425978          0.943483  14674.825044    19573.149277
# min      22.000000          0.000000  30000.000000        0.000000
# 25%      25.000000          2.000000  51900.000000        0.000000
# 50%      29.000000          2.000000  59500.000000    25600.000000
# 75%      38.000000          3.000000  71800.000000    38300.000000
# max      54.000000          4.000000  99300.000000    80500.000000
#
#         Total_salary         Price
# count    1581.000000   1581.000000
# mean    79625.996205  35597.722960
# std     25545.857768  13633.636545
# min     30000.000000  18000.000000
# 25%     60500.000000  25000.000000
# 50%     78000.000000  31000.000000
# 75%     95900.000000  47000.000000
# max    171000.000000  70000.000000

# %%
df.info() 
# to check basic information about dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1581 entries, 0 to 1580
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1581 non-null   int64
#  1   Gender            1528 non-null   object
#  2   Profession        1581 non-null   object
#  3   Marital_status    1581 non-null   object
#  4   Education         1581 non-null   object
#  5   No_of_Dependents  1581 non-null   int64
#  6   Personal_loan     1581 non-null   object
#  7   House_loan        1581 non-null   object
#  8   Partner_working   1581 non-null   object
#  9   Salary            1581 non-null   int64
#  10  Partner_salary    1475 non-null   float64
#  11  Total_salary      1581 non-null   int64
#  12  Price             1581 non-null   int64
#  13  Make              1581 non-null   object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 173.1+ KB

# %%
df.dtypes[df.dtypes==object]
# Out:
# Gender             object
# Profession         object
# Marital_status     object
# Education          object
# Personal_loan      object
# House_loan         object
# Partner_working    object
# Make               object
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.Gender.value_counts()
# Out:
# Gender
# Male      1199
# Female     327
# Femal        1
# Femle        1
# Name: count, dtype: int64

# %%
df.Gender.unique()
# Out:
# array(['Male', 'Femal', 'Female', nan, 'Femle'], dtype=object)

# %%
df.Profession.unique()
# Out:
# array(['Business', 'Salaried'], dtype=object)

# %%
 df.Marital_status.unique()
# Out:
# array(['Married', 'Single'], dtype=object)

# %%
df.Education.unique()
# Out:
# array(['Post Graduate', 'Graduate'], dtype=object)

# %%
df.Personal_loan.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df.House_loan.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
 df.Partner_working.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Profession', 'Marital_status', 'Education',
#        'No_of_Dependents', 'Personal_loan', 'House_loan', 'Partner_working',
#        'Salary', 'Partner_salary', 'Total_salary', 'Price', 'Make'],
#       dtype='object')

# %%
# Data cleaning

# %%
df.Gender = df.Gender.replace(["Femal","Femle"],["Female","Female"])
#rename misspelled words with correct word

# %%
df.Gender.unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
df.Gender=df.Gender.fillna("Male")
# fill  all the null value wit the mode value which is male

# %%
df.Partner_salary = df.Total_salary-df.Salary
# subtract the salary with total salary to fill missing values in partner salary

# %%
df.isnull().sum()
# to check it that all null value is treate perfectly
# Out:
# Age                 0
# Gender              0
# Profession          0
# Marital_status      0
# Education           0
# No_of_Dependents    0
# Personal_loan       0
# House_loan          0
# Partner_working     0
# Salary              0
# Partner_salary      0
# Total_salary        0
# Price               0
# Make                0
# dtype: int64

# %%
df.Gender.mode()
# to find the mode of Gender
# Out:
# 0    Male
# Name: Gender, dtype: object

# %% [markdown]
# ### create chart category col

# %%
sns.countplot(df,x=df.Gender,hue=df.Gender)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(df,x=df.Profession,hue=df.Profession)
# Out:
# <Axes: xlabel='Profession', ylabel='count'>

# %%
sns.countplot(df,x=df.Marital_status ,hue=df.Marital_status )
# Out:
# <Axes: xlabel='Marital_status', ylabel='count'>

# %%
sns.countplot(df,x=df. Education  ,hue=df. Education )
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
sns.countplot(df,x=df. Personal_loan   ,hue=df. Personal_loan   )
# Out:
# <Axes: xlabel='Personal_loan', ylabel='count'>

# %%
sns.countplot(df,x=df.  House_loan   ,hue=df.  House_loan   )
# Out:
# <Axes: xlabel='House_loan', ylabel='count'>

# %%
sns.countplot(df,x=df. Partner_working  ,hue=df.Partner_working   )
# Out:
# <Axes: xlabel='Partner_working', ylabel='count'>

# %%
sns.countplot(df,x=df.Make  ,hue=df.Make  )
# Out:
# <Axes: xlabel='Make', ylabel='count'>

# %% [markdown]
# #### plots for numircal data

# %%
df.Age.hist(bins=10)
# Out:
# <Axes: >

# %%
df.No_of_Dependents .hist(bins=10)
# Out:
# <Axes: >

# %%
sns.histplot(df.Partner_salary)
# Out:
# <Axes: xlabel='Partner_salary', ylabel='Count'>

# %%
sns.histplot(df.Salary)
# Out:
# <Axes: xlabel='Salary', ylabel='Count'>

# %%
sns.histplot(df.Total_salary)
# Out:
# <Axes: xlabel='Total_salary', ylabel='Count'>

# %%
sns.histplot(df.Price)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
df.groupby(["Gender","Make",])["Price"].sum()
# Out:
# Gender  Make
# Female  Hatchback      412000
#         SUV           9252000
#         Sedan         6031000
# Male    Hatchback    14996000
#         SUV           7328000
#         Sedan        18261000
# Name: Price, dtype: int64

# %%
pd.crosstab(df.Gender,df.Make,)
# Out:
# Make    Hatchback  SUV  Sedan
# Gender
# Female         15  173    141
# Male          567  124    561

# %%
#Main EDA

# %%
sns.countplot(df,x=df.Gender,hue=df.Make)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(df,x=df.Make,hue=df.Gender)
# Out:
# <Axes: xlabel='Make', ylabel='count'>

# %%
df.Gender.value_counts()  # balance imbalance
# Out:
# Gender
# Male      1252
# Female     329
# Name: count, dtype: int64

# %% [markdown]
# #### balance imbalance

# %%
male =  df[df.Gender=="Male"][["Gender","Make"]]

# %%
female =  df[df.Gender=="Female"][["Gender","Make"]]

# %%
female
# Out:
#       Gender       Make
# 1     Female        SUV
# 2     Female        SUV
# 3     Female        SUV
# 5     Female        SUV
# 6     Female        SUV
# ...      ...        ...
# 1350  Female  Hatchback
# 1389  Female  Hatchback
# 1503  Female  Hatchback
# 1518  Female  Hatchback
# 1536  Female  Hatchback
#
# [329 rows x 2 columns]

# %%
sam1=male.sample(329).groupby("Make").count().rename(columns={"Gender":"Male"}) # there is biasness possible

# %%
sam1
# Out:
#            Male
# Make
# Hatchback   153
# SUV          32
# Sedan       144

# %%
sam2=male.sample(329).groupby("Make").count().rename(columns={"Gender":"Male"})

# %%
sam2
# Out:
#            Male
# Make
# Hatchback   140
# SUV          32
# Sedan       157

# %%
sam3=male.sample(329).groupby("Make").count().rename(columns={"Gender":"Male"})

# %%
sam3
# Out:
#            Male
# Make
# Hatchback   156
# SUV          40
# Sedan       133

# %%
fem=female.sample(329).groupby("Make").count().rename(columns={"Gender":"Female"})

# %%
fem
# Out:
#            Female
# Make
# Hatchback      15
# SUV           173
# Sedan         141

# %%
suvm=[sam1.iloc[1][0],sam2.iloc[1][0],sam3.iloc[1][0]]
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_14220\3899908830.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   suvm=[sam1.iloc[1][0],sam2.iloc[1][0],sam3.iloc[1][0]]

# %%
suvm
# Out:
# [np.int64(32), np.int64(32), np.int64(40)]

# %%
suvf=[fem.iloc[1][0],fem.iloc[1][0],fem.iloc[1][0]]
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_14220\1197389391.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   suvf=[fem.iloc[1][0],fem.iloc[1][0],fem.iloc[1][0]]

# %%
suvf
# Out:
# [np.int64(173), np.int64(173), np.int64(173)]

# %%
SUV=pd.DataFrame({"Male":suvm,"Female":suvf},index=["Sample1","Sample2","Sample3"])

# %%
SUV
# Out:
#          Male  Female
# Sample1    32     173
# Sample2    32     173
# Sample3    40     173

# %%
SUV.plot.bar()        # in every sample female count is more than female is more buying suv
# it clearly visible that female is more buying
# Out:
# <Axes: >

# %%
hatchm=[sam1.iloc[0][0],sam2.iloc[0][0],sam3.iloc[0][0]]
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_14220\3135539326.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hatchm=[sam1.iloc[0][0],sam2.iloc[0][0],sam3.iloc[0][0]]

# %%
hatchm
# Out:
# [np.int64(153), np.int64(140), np.int64(156)]

# %%
hatchf=[fem.iloc[0][0],fem.iloc[0][0],fem.iloc[0][0]]
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_14220\3828958255.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hatchf=[fem.iloc[0][0],fem.iloc[0][0],fem.iloc[0][0]]

# %%
hatchf
# Out:
# [np.int64(15), np.int64(15), np.int64(15)]

# %%
HATCH=pd.DataFrame({"Male":hatchm,"Female":hatchf},index=["Sample1","Sample2","Sample3"])

# %%
HATCH
# Out:
#          Male  Female
# Sample1   153      15
# Sample2   140      15
# Sample3   156      15

# %%
HATCH.plot.bar()   # we clearly see that male are more interest in hatch
# Out:
# <Axes: >

# %%
sedm=[sam1.iloc[2][0],sam2.iloc[2][0],sam3.iloc[2][0]]
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_14220\3783597139.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sedm=[sam1.iloc[2][0],sam2.iloc[2][0],sam3.iloc[2][0]]

# %%
Sedm=[sam1.iloc[2][0],sam2.iloc[2][0],sam3.iloc[2][0]]
sedf=[fem.iloc[2][0],fem.iloc[2][0],fem.iloc[2][0]]
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_14220\3636105750.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Sedm=[sam1.iloc[2][0],sam2.iloc[2][0],sam3.iloc[2][0]]
# C:\Users\dell\AppData\Local\Temp\ipykernel_14220\3636105750.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sedf=[fem.iloc[2][0],fem.iloc[2][0],fem.iloc[2][0]]

# %%
sedf
# Out:
# [np.int64(141), np.int64(141), np.int64(141)]

# %%
sedm
# Out:
# [np.int64(144), np.int64(157), np.int64(133)]

# %%
SED=pd.DataFrame({"Male":sedm,"Female":sedf},index=["Sample1","Sample2","Sample3"])
SED
# Out:
#          Male  Female
# Sample1   144     141
# Sample2   157     141
# Sample3   133     141

# %%
SED.plot.bar()
# Out:
# <Axes: >

# %%
# both hav similar interest in sedan
# ( ALthough count of male is little higher than female

# %%
#Education 
# Marital
# Personal loan         # homwwork
# House Loan

# %% [markdown]
# ### Compair on basis on educatoin

# %%
kr = pd.crosstab(df.Education,df.Make)

# %%
kr
# Out:
# Make           Hatchback  SUV  Sedan
# Education
# Graduate             220  117    259
# Post Graduate        362  180    443

# %%
  k=  df.Education.value_counts()

# %%
postg =  df[df.Education=="Post Graduate"][["Education","Make"]]
#extract post graduate data for compariso

# %%
postg.head()
# Out:
#        Education Make
# 0  Post Graduate  SUV
# 1  Post Graduate  SUV
# 2  Post Graduate  SUV
# 4  Post Graduate  SUV
# 5  Post Graduate  SUV

# %%
Graduate = df[df.Education=="Graduate"][["Education","Make"]]
#extract graduate data for comparison

# %%
Graduate.head()
# Out:
#    Education Make
# 3   Graduate  SUV
# 7   Graduate  SUV
# 12  Graduate  SUV
# 14  Graduate  SUV
# 20  Graduate  SUV

# %%
post = postg.groupby("Make").count().rename(columns={"Education" : "Post Graduate"})

# %%
post
# Out:
#            Post Graduate
# Make
# Hatchback            362
# SUV                  180
# Sedan                443

# %%
graduate = Graduate.groupby("Make").count().rename(columns={"Education" : "Graduate"})

# %%
post.plot(kind="bar")
# we can see that the sedans is the top choice with post graduate leading 
# graduate show similar distribution but at lower count
# Out:
# <Axes: xlabel='Make'>

# %%
graduate.plot.bar()
plt.show()
# we can see that the sedans is the top choice and followed by hatch back  in both graph

# %%
sns.countplot(df,x=df.Education,hue=df.Make)
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %% [markdown]
# ### Compare on the basis of Profesion

# %%
sns.countplot(df,x=df.Make,hue=df.Profession)
# Out:
# <Axes: xlabel='Make', ylabel='count'>

# %% [markdown]
# ## Compare on martial status on which car purchase based on martial status Marital

# %%
df.Marital_status.value_counts()
# so we can see that the data is very imbalence so we can't make correct prediction or comparision 
# so we balance the dat so we can able to make compare of them
# Out:
# Marital_status
# Married    1443
# Single      138
# Name: count, dtype: int64

# %%
# so we balance the data on count of the variable of lower count of data

# %%
# extract data # Extractig Married data from the whole data 


Married=df[df.Marital_status=="Married"][["Marital_status","Make"]]

# %%
Married.head()
# Out:
#   Marital_status Make
# 0        Married  SUV
# 1        Married  SUV
# 2        Married  SUV
# 3        Married  SUV
# 4        Married  SUV

# %%
Single = df[df.Marital_status =="Single"][["Marital_status","Make"]]
# extract data for single

# %%
Single.head()
# Out:
#    Marital_status Make
# 15         Single  SUV
# 27         Single  SUV
# 35         Single  SUV
# 80         Single  SUV
# 93         Single  SUV

# %%
# now take a sample

sam_married1=Married.sample(138).groupby("Make").count().rename(columns={"Marital_status":"Married"})

# %%
sam_married1
# Out:
#            Married
# Make
# Hatchback       53
# SUV             20
# Sedan           65

# %%
sam_married2 =Married.sample(138).groupby("Make").count().rename(columns={"Marital_status":"Married"})

# %%
sam_married2
# Out:
#            Married
# Make
# Hatchback       39
# SUV             34
# Sedan           65

# %%
sam_married3 =Married.sample(138).groupby("Make").count().rename(columns={"Marital_status":"Married"})

# %%
sam_married3
# Out:
#            Married
# Make
# Hatchback       49
# SUV             33
# Sedan           56

# %%
sam_single=Single.sample(138).groupby("Make").count().rename(columns={"Marital_status":"Single"})

# %%
sam_single
# Out:
#            Single
# Make
# Hatchback      84
# SUV            16
# Sedan          38

# %% [markdown]
# ### compare suv on basis on marital status

# %%
suv_married=[sam_married1.iloc[1][0],sam_married2.iloc[1][0],sam_married3.iloc[1][0]]
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_14220\2416747041.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   suv_married=[sam_married1.iloc[1][0],sam_married2.iloc[1][0],sam_married3.iloc[1][0]]

# %%
suv_married
# Out:
# [np.int64(20), np.int64(34), np.int64(33)]

# %%
suv_single=[sam_single.iloc[1][0],sam_single.iloc[1][0],sam_single.iloc[1][0]]
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_14220\662745051.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   suv_single=[sam_single.iloc[1][0],sam_single.iloc[1][0],sam_single.iloc[1][0]]

# %%
suv_married
# Out:
# [np.int64(20), np.int64(34), np.int64(33)]

# %%
suv_marital=pd.DataFrame({"married":suv_married,"single":suv_single},index=["Sample1","Sample2","Sample3"])

# %%
suv_marital
# Out:
#          married  single
# Sample1       20      16
# Sample2       34      16
# Sample3       33      16

# %%
suv_marital.plot.bar()
plt.title("Marital Status vs  suv Car")
# Out:
# Text(0.5, 1.0, 'Marital Status vs  suv Car')

# %%
# so we can see that the married person is more interest in the suvthan single but also a least chosen

# %% [markdown]
# ## campair martial based on hatch back

# %%
hat_married=[sam_married1.iloc[0][0],sam_married2.iloc[0][0],sam_married3.iloc[0][0]]
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_14220\2216985752.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hat_married=[sam_married1.iloc[0][0],sam_married2.iloc[0][0],sam_married3.iloc[0][0]]

# %%
hat_single=[sam_single.iloc[0][0],sam_single.iloc[0][0],sam_single.iloc[0][0]]
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_14220\3972516713.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hat_single=[sam_single.iloc[0][0],sam_single.iloc[0][0],sam_single.iloc[0][0]]

# %%
hatch_marital=pd.DataFrame({"Married":hat_married,"Single":hat_single},index=["Sample1","Sample2","Sample3"])

# %%
hatch_marital.plot.bar()
plt.title("marital status for Hatch")
# Out:
# Text(0.5, 1.0, 'marital status for Hatch')

# %%
# BY this plot we can see that the single person is more interest in the hatch car

# %% [markdown]
# ### compare based on marital status for saden

# %%
saden_single=[sam_single.iloc[2][0],sam_single.iloc[2][0],sam_single.iloc[2][0]]
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_14220\58237149.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   saden_single=[sam_single.iloc[2][0],sam_single.iloc[2][0],sam_single.iloc[2][0]]

# %%
saden_single
# Out:
# [np.int64(38), np.int64(38), np.int64(38)]

# %%
saden_married=[sam_married1.iloc[2][0],sam_married2.iloc[2][0],sam_married3.iloc[2][0]]
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_14220\880718323.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   saden_married=[sam_married1.iloc[2][0],sam_married2.iloc[2][0],sam_married3.iloc[2][0]]

# %%
saden_marital=pd.DataFrame({"Married":saden_married,"Single":saden_single},index=["Sample1","Sample2","Sample3"])

# %%
saden_marital.plot.bar()
# Out:
# <Axes: >

# %%
 #Married individuals prefer Sedans more than Singles.

# %%
sns.countplot(df,x=df.Marital_status,hue= "Make")
# # Here we have not taken the sample we have just compair with whole data and result is still same
# the married person is more interest in sedan,single person is lean toward hatchback 
# and the suv is the lest chosen one but married individuals have more interest in suv than single
# Out:
# <Axes: xlabel='Marital_status', ylabel='count'>

# %% [markdown]
# ### personal
# home loan

# %% [markdown]
# # Compairing on the basis of PERSONAL LOAN

# %%
# counting number of people taken Personal Loan 
df.Personal_loan.value_counts()
# Out:
# Personal_loan
# Yes    792
# No     789
# Name: count, dtype: int64

# %%
Yes=df[df.Personal_loan=="Yes"] [["Personal_loan","Make"]] 
# extract data for yes

# %%
Yes.head()
# Out:
#    Personal_loan Make
# 1            Yes  SUV
# 3            Yes  SUV
# 6            Yes  SUV
# 10           Yes  SUV
# 12           Yes  SUV

# %%
No=df[df.Personal_loan=="No"] [["Personal_loan","Make"]]
# extract data for no

# %%
No
# Out:
#      Personal_loan       Make
# 0               No        SUV
# 2               No        SUV
# 4               No        SUV
# 5               No        SUV
# 7               No        SUV
# ...            ...        ...
# 1571            No  Hatchback
# 1576            No  Hatchback
# 1577            No  Hatchback
# 1578            No  Hatchback
# 1580            No  Hatchback
#
# [789 rows x 2 columns]

# %%
Pyes=Yes.groupby("Make").count().rename(columns={"Personal_loan":"Yes"})

# %%
Pyes
# Out:
#            Yes
# Make
# Hatchback  291
# SUV        116
# Sedan      385

# %%
Pno=No.groupby("Make").count().rename(columns={"Personal_loan":"No"})

# %%
Pno
# Out:
#             No
# Make
# Hatchback  291
# SUV        181
# Sedan      317

# %%
suv_yes=(116)

# %%
suv_no=(181)

# %%
SUV_personal_loan=pd.DataFrame({"yes":suv_yes,"no":suv_no},index=["SUV"])
# make data frame for visulization

# %%
SUV_personal_loan
# Out:
#      yes   no
# SUV  116  181

# %%
SUV_personal_loan.plot.bar()
# Out:
# <Axes: >

# %%
# we can see that  suv is top choice for no

# %%
sedan_yes=(385)

# %%
sedan_no=(317)

# %%
sedan_personal_loan=pd.DataFrame({"yes":sedan_yes,"no":sedan_no},index=["Sedan"])

# %%
sedan_personal_loan
# Out:
#        yes   no
# Sedan  385  317

# %%
sedan_personal_loan.plot.bar()
# Out:
# <Axes: >

# %%
# we can see that  sedan is top choice for yes 
# but there is not much difference

# %%
hatch_yes=(291)

# %%
hatch_no=(291)

# %%
hatch_personal_loan=pd.DataFrame({"yes":hatch_yes,"no":hatch_no},index=["Hatch"])

# %%
hatch_personal_loan.plot.bar()
# Out:
# <Axes: >

# %%
# hatchback is similar interest there is no difference

# %%
sns.countplot(df,x=df.Personal_loan,hue=df.Make)
# Out:
# <Axes: xlabel='Personal_loan', ylabel='count'>

# %%
# the sedan is more intrest by with both type of yes,no  but more by yes 
# it is followed by the hatchback  interest at similar level
 # least interest in suv but more purchesed by NO

# %% [markdown]
# # Compairing on the basis of HOUSE LOAN

# %%
# counting number of people taken Home Loan 
df.House_loan.value_counts()
# Out:
# House_loan
# No     1054
# Yes     527
# Name: count, dtype: int64

# %%
# Since there is differance in the data therefore we will take some data  to make the data equal

# %%
# Extractig people who have  not taken loan from the whole data 

home_loan_no=df[df.House_loan=="No"][["House_loan","Make"]]

# %%
home_loan_no.head()
# Out:
#   House_loan Make
# 0         No  SUV
# 1         No  SUV
# 2         No  SUV
# 3         No  SUV
# 4         No  SUV

# %%
# Extractig people who have taken loan from the whole data 

home_loan_yes=df[df.House_loan=="Yes"][["House_loan","Make"]]

# %%
home_loan_yes.head()
# Out:
#     House_loan   Make
# 144        Yes  Sedan
# 145        Yes  Sedan
# 147        Yes  Sedan
# 149        Yes  Sedan
# 152        Yes  Sedan

# %%
# We will extract the sample of people who have not taken HOME loan equal to people who have taken loan by sampling  method

# %%
# taking sample of people who have not taken loan equal to people taken loan and group them by Make and rename it so we can identify easily

sam1_housloan_no=home_loan_no.sample(527).groupby("Make").count().rename(columns={"House_loan":"House_loan_not_taken"})

# %%
sam1_housloan_no
# Out:
#            House_loan_not_taken
# Make
# Hatchback                   169
# SUV                         135
# Sedan                       223

# %%
# we take more than 1 sample because there is chance of bainess 
sam2_housloan_no=home_loan_no.sample(527).groupby("Make").count().rename(columns={"House_loan":"House_loan_not_taken"})

# %%
sam2_housloan_no
# Out:
#            House_loan_not_taken
# Make
# Hatchback                   175
# SUV                         135
# Sedan                       217

# %%
sam3_housloan_no=home_loan_no.sample(527).groupby("Make").count().rename(columns={"House_loan":"House_loan_not_taken"})

# %%
sam3_housloan_no
# Out:
#            House_loan_not_taken
# Make
# Hatchback                   170
# SUV                         153
# Sedan                       204

# %%
# taking sample of peopl who have taken loan and group them by Make 


sam_houseloan_yes=home_loan_yes.sample(527).groupby("Make").count().rename(columns={"House_loan":"House_loan_taken"})

# %%
sam_houseloan_yes
# Out:
#            House_loan_taken
# Make
# Hatchback               235
# SUV                      22
# Sedan                   270

# %% [markdown]
# ## Compairing Number of SUV on the basis of House Loan

# %%
# count of SUV owned by people who have not taken house loan 
house_loan_no_suv=[sam1_housloan_no.iloc[1][0],sam2_housloan_no.iloc[1][0],sam3_housloan_no.iloc[1][0]]
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_14220\531822787.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   house_loan_no_suv=[sam1_housloan_no.iloc[1][0],sam2_housloan_no.iloc[1][0],sam3_housloan_no.iloc[1][0]]

# %%
house_loan_no_suv
# Out:
# [np.int64(135), np.int64(135), np.int64(153)]

# %%
house_loan_yes_suv=[sam_houseloan_yes.iloc[1][0],sam_houseloan_yes.iloc[1][0],sam_houseloan_yes.iloc[1][0]]
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_14220\1438837646.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   house_loan_yes_suv=[sam_houseloan_yes.iloc[1][0],sam_houseloan_yes.iloc[1][0],sam_houseloan_yes.iloc[1][0]]

# %%
house_loan_yes_suv
# Out:
# [np.int64(22), np.int64(22), np.int64(22)]

# %%
# Creating DataFrame on the bases of house loan taken or not 
house_loan_suv=pd.DataFrame({"yes":house_loan_yes_suv,"no":house_loan_no_suv},index=["Sample1","Sample2","Sample3"])
house_loan_suv
# Out:
#          yes   no
# Sample1   22  135
# Sample2   22  135
# Sample3   22  153

# %%
house_loan_suv.plot.bar() 
# to visual graph
# Out:
# <Axes: >

# %%
# by this barchart we can see that the people that have not taken loan are more interest in the suv

# %% [markdown]
# # Compairing Number of HatchBack on the bases of House loan

# %%
# count of hatchback owned by people who have not taken house loan 
house_loan_no_hatchback=[sam1_housloan_no.iloc[0][0],sam2_housloan_no.iloc[0][0],sam3_housloan_no.iloc[0][0]]
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_14220\1750062836.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   house_loan_no_hatchback=[sam1_housloan_no.iloc[0][0],sam2_housloan_no.iloc[0][0],sam3_housloan_no.iloc[0][0]]

# %%
house_loan_yes_hatchback=[sam_houseloan_yes.iloc[0][0],sam_houseloan_yes.iloc[0][0],sam_houseloan_yes.iloc[0][0]]
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_14220\1711193529.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   house_loan_yes_hatchback=[sam_houseloan_yes.iloc[0][0],sam_houseloan_yes.iloc[0][0],sam_houseloan_yes.iloc[0][0]]

# %%
house_loan_yes_hatchback
# Out:
# [np.int64(235), np.int64(235), np.int64(235)]

# %%
house_loan_no_hatchback
# Out:
# [np.int64(169), np.int64(175), np.int64(170)]

# %%
# Creating DataFrame on the bases of house loan taken or not 
house_loan_hatchback=pd.DataFrame({"yes":house_loan_yes_hatchback,"no":house_loan_no_hatchback},index=["Sample1","Sample2","Sample3"])
house_loan_hatchback
# Out:
#          yes   no
# Sample1  235  169
# Sample2  235  175
# Sample3  235  170

# %%
house_loan_hatchback.plot.bar()
# Out:
# <Axes: >

# %%
#we can see that they have nearly similar interest but house taken are more purchesed

# %% [markdown]
# # Compairing Number of Sedan  on the bases of House loan

# %%
# count of Sedan owned by people who have not taken house loan 
house_loan_no_Sedan=[sam1_housloan_no.iloc[2][0],sam2_housloan_no.iloc[2][0],sam3_housloan_no.iloc[2][0]]
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_14220\3581655621.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   house_loan_no_Sedan=[sam1_housloan_no.iloc[2][0],sam2_housloan_no.iloc[2][0],sam3_housloan_no.iloc[2][0]]

# %%
house_loan_no_Sedan
# Out:
# [np.int64(223), np.int64(217), np.int64(204)]

# %%
house_loan_yes_Sedan=[sam_houseloan_yes.iloc[0][0],sam_houseloan_yes.iloc[0][0],sam_houseloan_yes.iloc[0][0]]
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_14220\1000508018.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   house_loan_yes_Sedan=[sam_houseloan_yes.iloc[0][0],sam_houseloan_yes.iloc[0][0],sam_houseloan_yes.iloc[0][0]]

# %%
house_loan_yes_Sedan
# Out:
# [np.int64(235), np.int64(235), np.int64(235)]

# %%
# Creating DataFrame on the bases of house loan taken or not 
house_loan_Sedan=pd.DataFrame({"yes":house_loan_yes_Sedan,"no":house_loan_no_Sedan},index=["Sample1","Sample2","Sample3"])
house_loan_Sedan
# Out:
#          yes   no
# Sample1  235  223
# Sample2  235  217
# Sample3  235  204

# %%
house_loan_Sedan.plot.bar()
# Out:
# <Axes: >

# %%
# we can see that they have nearly similar interest but house taken are more purchesed

# %%
#comparion at all car basis of house loan
sns.countplot(df,x=df.House_loan,hue=df.Make)
# Out:
# <Axes: xlabel='House_loan', ylabel='count'>

# %% [markdown]
# #### from this chart we can see that the sedan is the more dominate in both house loan taken and not
# ####  hatchback is more dominate in yes but there is not much difference
# #### There is high difference in suv is more purchese buy by the people that have not taken loan

# %% [markdown]
# #### we can see the the people that have not taken house loan have purchesed more car then taken house loan

# %% [markdown]
# # Multivariate

# %% [markdown]
# # Profession gender make

# %%
new =  pd.DataFrame(df.groupby(["Gender","Profession","Make"])["Make"].count())

# %%
new
# Out:
#                              Make
# Gender Profession Make
# Female Business   SUV          55
#                   Sedan        50
#        Salaried   Hatchback    15
#                   SUV         118
#                   Sedan        91
# Male   Business   Hatchback   290
#                   SUV          34
#                   Sedan       256
#        Salaried   Hatchback   277
#                   SUV          90
#                   Sedan       305

# %% [markdown]
# ### Female Business comparison of car

# %%
k=new.loc["Female"].loc["Business"].loc["SUV"]

# %%
k # female business data for suv
# Out:
# Make    55
# Name: SUV, dtype: int64

# %%
m=new.loc["Female"].loc["Business"].loc["Sedan"]

# %%
m   # female business data for sedan
# Out:
# Make    50
# Name: Sedan, dtype: int64

# %%
hatch=(0)  # there is no data for hatch so we put zero in the place

# %%
newk=pd.DataFrame({"SUV":k,"Sedan":m,"Hatchback":hatch})   
# put in the dataframe for visulaziation

# %%
newk
# Out:
#       SUV  Sedan  Hatchback
# Make   55     50          0

# %%
newk.plot.bar()    # for visual the comparision
plt.title("Female and Business vS make")
# Out:
# Text(0.5, 1.0, 'Female and Business vS make')

# %%
# So we can see that female bussness are zero interest in hatchback ,
# most interest in suv follewed by sedan

# %% [markdown]
# ### Female salaried comparison of car

# %%
fem_sal_suv=new.loc["Female"].loc["Salaried"].loc["SUV"]

# %%
fem_sal_suv   # female Salaried data for suv
# Out:
# Make    118
# Name: SUV, dtype: int64

# %%
fem_sal_sed=new.loc["Female"].loc["Salaried"].loc["Sedan"]

# %%
fem_sal_sed    # female Salaried data for sedan
# Out:
# Make    91
# Name: Sedan, dtype: int64

# %%
fem_sal_hatch=new.loc["Female"].loc["Salaried"].loc["Hatchback"]

# %%
fem_sal_hatch    # female Salaried data for hatchback
# Out:
# Make    15
# Name: Hatchback, dtype: int64

# %%
female_sal=pd.DataFrame({"SUV":fem_sal_suv,"Sedan":fem_sal_sed,"Hatchback":fem_sal_hatch})
# put in the dataframe for visulaziation

# %%
female_sal
# Out:
#       SUV  Sedan  Hatchback
# Make  118     91         15

# %%
female_sal.plot.bar()   # for visual the comparision
plt.title("Female and Salaried vS make")
# Out:
# Text(0.5, 1.0, 'Female and Salaried vS make')

# %% [markdown]
# * we can see that the female salaried person are more interest in  suv and then sedan
# * and almost no interest in hatchback
#  * from above two graph we can see that the suv is interest by the salariedand buseness female
#  and hatchback is not interest by them

# %% [markdown]
# ### Male Business comparison of car

# %%
m_bus_suv=new.loc["Male"].loc["Business"].loc["SUV"]

# %%
m_bus_suv # for checked data 
# Male Business data for suv
# Out:
# Make    34
# Name: SUV, dtype: int64

# %%
m_bus_sedan=new.loc["Male"].loc["Business"].loc["Sedan"]

# %%
m_sal_sedan
# Male Business data for sedan
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[216], line 1
# ----> 1 m_sal_sedan
#       2 # Male Business data for sedan
#
# NameError: name 'm_sal_sedan' is not defined

# %%
m_bus_Hatchback=new.loc["Male"].loc["Business"].loc["Hatchback"]

# %%
m_sal_Hatchback
# Male Business data for hatchback

# %%
male_business=pd.DataFrame({"SUV":m_bus_suv,"Sedan":m_bus_sedan,"Hatchback":m_bus_Hatchback})
# put in the dataframe for visulaziation

# %%
male_business.plot.bar()
plt.title("male and Business vS make")
 # for visual the comparision

# %%
# we can see from the chart that male business man are interst in Hatchback and Sedan 
# and not  highly interest in suv

# %% [markdown]
# ## Comparsion Male Salaried on the  car

# %%
m_sal_suv=new.loc["Male"].loc["Salaried"].loc["SUV"]
# male salaried suv data

# %%
m_sal_suv

# %%
m_sal_sedan=new.loc["Male"].loc["Salaried"].loc["Sedan"]

# %%
m_sal_sedan

# %%
m_sal_hatch=new.loc["Male"].loc["Salaried"].loc["Hatchback"]

# %%
m_sal_hatch

# %%
#All data is collected

# %%
male_salaried=pd.DataFrame({"SUV":m_sal_suv,"Sedan":m_sal_sedan,"Hatchback":m_sal_Hatchback})

# %%
male_salaried.plot.bar()
plt.title("male and Salaried vS make")

# %%
# we can see from the chart that male business man are interst in Hatchback and Sedan 
# and not highly interest in suv

# %% [markdown]
# ## Now the total insight we get from this FOR FEMALE
# * Female business and salaried  are more interset in the suv and followed by sedan
# * they are is not highly interest in the Hatchback

# %% [markdown]
# ### ADIVSE :- IF THERE IS A FEMALE SALARIED OR BUSSINESS SHOW THEM FIRST SUV AND SEDAN

# %% [markdown]
# ## Now the total insight we get from this FOR MALE
# THE MALE BUSINESS OR SALARIED ARE MORE INTEREST IN THE HATCHBACK AND SEDAN
# AND LESS INTERSEST  IN SUV

# %%
new.plot.bar()

# %% [markdown]
# # Gender marital status

# %%
new2 =  pd.DataFrame(df.groupby(["Gender","Marital_status","Make"])["Make"].count())

# %%
new2.plot.bar()

# %%
new3 =  pd.DataFrame(df.groupby(["Gender","Partner_working","Make"])["Make"].count())

# %%
new3.plot.bar()

# %% [markdown]
# ## gender, partner_working,make   HW
